# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', None, 'display.max_columns', None)

# %%
nb  = pd.read_html(f"https://www.basketball-reference.com/teams/DET/2023.html")

# %%
nb[0]
# Out:
#     No.            Player Pos    Ht   Wt         Birth Date Unnamed: 6 Exp  \
# 0    23      Mark Aguirre  SF   6-6  232  December 10, 1959         us   8
# 1    20   William Bedford   C   7-0  225  December 14, 1963         us   2
# 2     4        Joe Dumars  SG   6-3  190       May 24, 1963         us   4
# 3    53     James Edwards   C   7-0  225  November 22, 1955         us  12
# 4    33    Dave Greenwood  PF   6-9  222       May 27, 1957         us  10
# 5    35    Scott Hastings  PF  6-10  235       June 3, 1960         us   7
# 6    12  Gerald Henderson  PG   6-2  175   January 16, 1956         us  10
# 7    15    Vinnie Johnson  SG   6-2  200  September 1, 1956         us  10
# 8     3    Stan Kimbrough  PG  5-11  153     April 24, 1966         us   R
# 9    40     Bill Laimbeer   C  6-11  245       May 19, 1957         us   9
# 10   35       Ralph Lewis  SG   6-6  200     March 28, 1963         us   2
# ...

# %%
team = nb[0].copy()
# team[['Ht']]
# for x in team.index:
# Convert height from format 'ft-in' to inches
team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
# Calculate average height
average_height = team['Ht'].mean()
average_weight = team['Wt'].mean()
team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
average_height
average_weight
average_exp = team['Exp'].mean()
average_exp
# Out:
# 3.1363636363636362

# %%
import time
team_info = pd.DataFrame()
team_stats = pd.DataFrame()
#Detroit Pistons
for year in range(2000, 2024):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/DET/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Detroit Pistons'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Detroit Pistons*', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Boston Celtics
for year in range(2000, 2024):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/BOS/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Boston Celtics'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Boston Celtics', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
# Atlanta Hawks
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/ATL/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Atlanta Hawks'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Atlanta Hawks', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Chicago Bulls
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/CHI/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Chicago Bulls'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Chicago Bulls', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    # Add a delay of 3 seconds between each request
    time.sleep(3)
#Cleveland Cavaliers
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/CLE/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Cleveland Cavaliers'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Cleveland Cavaliers', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Dallas Mavericks
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/DAL/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Dallas Mavericks'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Dallas Mavericks', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Denver Nuggets
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/DEN/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Denver Nuggets'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Denver Nuggets', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Golden State Warriors
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/GSW/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Golden State Warriors'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Golden State Warriors', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Houston Rockets
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/HOU/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Houston Rockets'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Houston Rockets', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Indiana Pacers
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/IND/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Indiana Pacers'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Indiana Pacers', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Los Angeles Clippers
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/LAC/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Los Angeles Clippers'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Los Angeles Clippers', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Los Angeles Lakers
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/LAL/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Los Angeles Lakers'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Los Angeles Lakers', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Memphis Grizzlies
for year in range(2000, 2025):
    if year > 2001: 
        nb  = pd.read_html(f"https://www.basketball-reference.com/teams/MEM/{year}.html")
    else:
        nb  = pd.read_html(f"https://www.basketball-reference.com/teams/VAN/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    if year > 2001:
        team['Team'] = 'Memphis Grizzlies'
    else:
        team['Team'] = 'Vancouver Grizzlies'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    if year > 2001:
        team_stats = team_stats.append({'Team': 'Memphis Grizzlies', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    else:
        team_stats = team_stats.append({'Team': 'Vancouver Grizzlies', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Miami Heat
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/MIA/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Miami Heat'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Miami Heat', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Milwaukee Bucks
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/MIL/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Milwaukee Bucks'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Milwaukee Bucks', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Minnesota Timberwolves
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/MIN/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Minnesota Timberwolves'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Minnesota Timberwolves', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#New Orleans Pelicans
for year in range(2000, 2025):
    if year == 2006 or year == 2007:
        nb  = pd.read_html(f"https://www.basketball-reference.com/teams/NOK/{year}.html")
    elif year > 2013:
        nb  = pd.read_html(f"https://www.basketball-reference.com/teams/NOP/{year}.html")
    else:
        nb  = pd.read_html(f"https://www.basketball-reference.com/teams/NOH/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    if year == 2006 or year == 2007:
        team['Team'] = 'New Orleans/Oklahoma City Hornets'
    elif year > 2013:
        team['Team'] = 'New Orleans Pelicans'
    else:
        team['Team'] = 'New Orleans Hornets'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    if year == 2006 or year == 2007:
        team_stats = team_stats.append({'Team': 'New Orleans/Oklahoma City Hornets', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    elif year > 2013:
        team_stats = team_stats.append({'Team': 'New Orleans Pelicans', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    else:
        team_stats = team_stats.append({'Team': 'New Orleans Hornets', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#New York Knicks
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/NYK/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'New York Knicks'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'New York Knicks', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Oklahoma City Thunder
for year in range(2000, 2025):
    if year < 2009:
        nb  = pd.read_html(f"https://www.basketball-reference.com/teams/SEA/{year}.html")
    else:
        nb  = pd.read_html(f"https://www.basketball-reference.com/teams/OKC/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    if year < 2009:
        team['Team'] = 'Seattle SuperSonics'
    else:
        team['Team'] = 'Oklahoma City Thunder'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    if year < 2009:
        team_stats = team_stats.append({'Team': 'Seattle SuperSonics', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    else:
        team_stats = team_stats.append({'Team': 'Oklahoma City Thunder', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Orlando Magic
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/ORL/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Orlando Magic'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Orlando Magic', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Philadelphia 76ers
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/PHI/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Philadelphia 76ers'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Philadelphia 76ers', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Phoenix Suns
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/PHO/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Phoenix Suns'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Phoenix Suns', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Portland Trail Blazers
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/POR/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Portland Trail Blazers'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Portland Trail Blazers', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Sacramento Kings
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/SAC/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Sacramento Kings'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Sacramento Kings', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#San Antonio Spurs
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/SAS/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'San Antonio Spurs'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'San Antonio Spurs', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Toronto Raptors
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/TOR/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Toronto Raptors'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Toronto Raptors', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Utah Jazz
for year in range(2000, 2025):
    nb  = pd.read_html(f"https://www.basketball-reference.com/teams/UTA/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    team['Team'] = 'Utah Jazz'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    team_stats = team_stats.append({'Team': 'Utah Jazz', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Washington Wizards
for year in range(2000, 2025):
    if year < 1998:
        nb  = pd.read_html(f"https://www.basketball-reference.com/teams/WSB/{year}.html")
    else:
        nb  = pd.read_html(f"https://www.basketball-reference.com/teams/WAS/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    if year < 1998:
        team['Team'] = 'Washington Bullets'
    else:
        team['Team'] = 'Washington Wizards'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    if year < 1998:
        team_stats = team_stats.append({'Team': 'Washington Bullets', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    else:
        team_stats = team_stats.append({'Team': 'Washington Wizards', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Brooklyn Nets
for year in range(2000, 2025):
    if year < 2013:
        nb  = pd.read_html(f"https://www.basketball-reference.com/teams/NJN/{year}.html")
    else: 
        nb  = pd.read_html(f"https://www.basketball-reference.com/teams/BRK/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    if year < 2012:
        team['Team'] = 'New Jersey Nets'
    else:
        team['Team'] = 'Brooklyn Nets'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    if year < 2013:
        team_stats = team_stats.append({'Team': 'New Jersey Nets', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    else:
        team_stats = team_stats.append({'Team': 'Brooklyn Nets', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
#Charlotte Hornets
for year in range(2000, 2025):
    if year < 2003:
        nb  = pd.read_html(f"https://www.basketball-reference.com/teams/CHH/{year}.html")
    elif year == 2003 or year == 2004:
        continue
    elif year > 2014:
        nb  = pd.read_html(f"https://www.basketball-reference.com/teams/CHO/{year}.html")
    else:
        nb  = pd.read_html(f"https://www.basketball-reference.com/teams/CHA/{year}.html")
    team = nb[0].copy()
    team['Ht'] = team['Ht'].apply(lambda x: int(x.split('-')[0]) * 12 + int(x.split('-')[1]))
    team['Exp'] = team['Exp'].apply(lambda x: int(str(x).replace('R', '0')))
    team['Year'] = year
    if year < 2003:
        team['Team'] = 'Charlotte Hornets'
    elif year < 2015:
        team['Team'] = 'Charlotte Bobcats'
    else:
        team['Team'] = 'Charlotte Hornets'
    team_info = team_info.append(team)
    
    # Calculate mean height and experience for the team
    mean_ht = team['Ht'].mean()
    mean_exp = team['Exp'].mean()
    mean_wt = team['Wt'].mean()
    
    # Append the stats to the team_stats dataframe
    if year < 2003:
        team_stats = team_stats.append({'Team': 'Charlotte Hornets', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    elif year < 2015:
        team_stats = team_stats.append({'Team': 'Charlotte Bobcats', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    else:
        team_stats = team_stats.append({'Team': 'Charlotte Hornets', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
    time.sleep(3)
# Out:
# C:\Users\jeg5086\AppData\Local\Temp\ipykernel_2916\177709791.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team)
# C:\Users\jeg5086\AppData\Local\Temp\ipykernel_2916\177709791.py:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_stats = team_stats.append({'Team': 'Detroit Pistons*', 'Year': year, 'Mean Ht': mean_ht, 'Mean Wt': mean_wt ,'Mean Exp': mean_exp}, ignore_index=True)
# C:\Users\jeg5086\AppData\Local\Temp\ipykernel_2916\177709791.py:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_info = team_info.append(team)
# ...

# %%
team_info.to_excel('team_info_2024.xlsx', index=False)

# %%
team_stats.to_excel('team_stats_2024.xlsx', index=False)

# %%
team_info
# Out:
#        No.                     Player Pos  Ht   Wt          Birth Date  \
# 0     23.0                 Jaden Ivey  SG  76  195   February 13, 2002
# 1     25.0              Marcus Sasser  PG  74  195  September 21, 2000
# 2      9.0             Ausar Thompson  SF  79  215    January 30, 2003
# 3     13.0              James Wiseman   C  84  240      March 31, 2001
# 4      2.0            Cade Cunningham  PG  78  220  September 25, 2001
# 5      0.0                Jalen Duren   C  82  250   November 18, 2003
# 6     28.0             Isaiah Stewart  PF  80  250        May 22, 2001
# 7     31.0              Evan Fournier  SG  78  205    October 29, 1992
# 8     14.0              Malachi Flynn  PG  73  175        May 10, 1998
# 9     17.0              Stanley Umude  SG  78  210      April 12, 1999
# 10     7.0             Troy Brown Jr.  SF  78  215       July 28, 1999
# 11     8.0          Jared Rhoden (TW)  SG  78  210     August 27, 1999
# ...
